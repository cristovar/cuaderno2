# %% [markdown]
# <a href="https://colab.research.google.com/github/cristovar/cuaderno2/blob/main/Algoritmos_CristobalTovar_AG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad Guiada 1 de Algoritmos de Optimizacion
#
# Nombre: Cristobal Tovar Quiroz
#
# https://colab.research.google.com/drive/1SRlTLrvC75PnLhrAOhyD8uPmb0NSoJfN?usp=sharing
#
# https://github.com/cristovar/ALGORITMOS-DE-OPTIMIZACI-N.git

# %%
#Torres de Hanoi - Divide y venceras
################################################################################


################################################################

def Mover (ori, to): 
	print("Mueva un disco de {} a {}".format(ori,to))

def Torres_Hanoi(N, desde, pivote, hasta):
  if N == 0:
    	return
  Torres_Hanoi(N-1, desde, hasta, pivote)
  Mover(desde, hasta)
  Torres_Hanoi(N-1, pivote, desde, hasta)

Torres_Hanoi(3, 'A', 'B', 'C',)


################################################################
# Out:
# Mueva un disco de A a C
# Mueva un disco de A a B
# Mueva un disco de C a B
# Mueva un disco de A a C
# Mueva un disco de B a A
# Mueva un disco de B a C
# Mueva un disco de A a C

# %%
#Cambio de monedas - Técnica voraz
################################################################################

################################################################
def cambio_monedas(CANTIDAD,SISTEMA):
  solucion=[0 for j in range (len(SISTEMA))]
  print(solucion)
  valor_acumulado = CANTIDAD
  SISTEMA.sort(reverse=True)
  for i in range (len(SISTEMA)):
    monedas = int( (valor_acumulado)/SISTEMA[i])
    valor_acumulado -= monedas*SISTEMA[i]
    solucion[i]= monedas
  if valor_acumulado==0:
    return solucion
  else:
    return print('No hay cambio')

#....

################################################################
SISTEMA = [50,100,200,500,1000,2000,5000,10000]
print(cambio_monedas(59800,SISTEMA))
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]
# [5, 1, 2, 0, 1, 1, 1, 0]

# %%
#N Reinas - Vuelta Atrás()
################################################################################

#Verifica que en la solución parcial no hay amenzas entre reinas
################################################################
def es_prometedora(SOLUCION,etapa):
################################################################
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:       
      return False
  
    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True

#Traduce la solución al tablero
################################################################
def escribe_solucion(S):
################################################################
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")



#Proceso principal de N-Reinas
################################################################
def reinas(N,solucion=[],etapa=0): 
  if len(solucion)==0:
    solucion = [0 for j in range(N)]
  for i in range(1,N+1):
    solucion[etapa] = i
    if es_prometedora(solucion,etapa):
      if etapa==N-1:
        print('La solución es ',solucion)
        escribe_solucion(solucion)
      else:
        reinas(N,solucion,etapa+1)
    else:
      #print('\nNo cumple las restricciones')
      None
    solucion[etapa] = 0
################################################################
### ....
N = int(input("Escriba el número de reinas:\n"))
solucion = []
for i in range(N):
	solucion.append(0)
etapa = 0
reinas(N,solucion,etapa)
# Out:
# Escriba el número de reinas:
# 8
# La solución es  [1, 5, 8, 6, 3, 7, 2, 4]
#
#  X  -  -  -  -  -  -  -
#  -  -  -  -  -  -  X  -
#  -  -  -  -  X  -  -  -
#  -  -  -  -  -  -  -  X
#  -  X  -  -  -  -  -  -
#  -  -  -  X  -  -  -  -
#  -  -  -  -  -  X  -  -
#  -  -  X  -  -  -  -  - La solución es  [1, 6, 8, 3, 7, 4, 2, 5]
#
#  X  -  -  -  -  -  -  -
#  -  -  -  -  -  -  X  -
#  -  -  -  X  -  -  -  -
#  -  -  -  -  -  X  -  -
#  -  -  -  -  -  -  -  X
#  -  X  -  -  -  -  -  -
#  -  -  -  -  X  -  -  -
#  -  -  X  -  -  -  -  - La solución es  [1, 7, 4, 6, 8, 2, 5, 3]
#
#  X  -  -  -  -  -  -  -
#  -  -  -  -  -  X  -  -
#  -  -  -  -  -  -  -  X
#  -  -  X  -  -  -  -  -
#  -  -  -  -  -  -  X  -
#  -  -  -  X  -  -  -  -
#  -  X  -  -  -  -  -  -
#  -  -  -  -  X  -  -  - La solución es  [1, 7, 5, 8, 2, 4, 6, 3]
#
#  X  -  -  -  -  -  -  -
#  -  -  -  -  X  -  -  -
#  -  -  -  -  -  -  -  X
#  -  -  -  -  -  X  -  -
#  -  -  X  -  -  -  -  -
#  -  -  -  -  -  -  X  -
# ...

# %%
#Viaje por el rio - Programación dinámica
################################################################################

TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

#999 se puede sustituir por float("inf")


#Calculo de la matriz de PRECIOS y RUTAS
################################################################  
def Precios(TARIFAS):
  N = len(TARIFAS[0])
  PRECIOS = [[9999]*N for i in [9999]*N]
  RUTAS = [[""]*N for i in [9999]*N]
  for i in range(N-1):
    for j in range(i+1,N):
      MIN = TARIFAS[i][j]
      RUTAS[i][j] = i
      
      for k in range(i,j):
        if PRECIOS[i][k]+ TARIFAS[k][j] < MIN:
          MIN = PRECIOS[i][k]+ TARIFAS[k][j]
          RUTAS[i][j] = k
      PRECIOS[i][j] = MIN
  return PRECIOS, RUTAS

PRECIOS,RUTA = Precios(TARIFAS)  
#print(PRECIOS[0][6])

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")  
for i in range(len(TARIFAS)):
  print(RUTA[i]) 

#Determinar la ruta con Recursividad
################################################################
def calcular_ruta(RUTAS, desde, hasta):

  if desde == hasta: 
    #print("Ir a :" + str(desde)) 
    return desde 
  else: return str(calcular_ruta(RUTAS, desde, RUTAS[desde][hasta])) + ',' + str(RUTAS[desde][hasta]) 
                  
print("\nLa ruta es:") 
calcular_ruta(RUTA,0,6)
# Out:
# PRECIOS
# [9999, 5, 4, 3, 8, 8, 11]
# [9999, 9999, 999, 2, 3, 8, 7]
# [9999, 9999, 9999, 1, 6, 4, 7]
# [9999, 9999, 9999, 9999, 5, 6, 9]
# [9999, 9999, 9999, 9999, 9999, 999, 4]
# [9999, 9999, 9999, 9999, 9999, 9999, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# ['', 0, 0, 0, 1, 2, 5]
# ['', '', 1, 1, 1, 3, 4]
# ['', '', '', 2, 3, 2, 5]
# ['', '', '', '', 3, 3, 3]
# ['', '', '', '', '', 4, 4]
# ['', '', '', '', '', '', 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# '0,0,2,5'
